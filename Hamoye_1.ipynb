# %% [markdown]
# # Question 1
#
# If you’re given two lists:
#
# A = [1,2,3,4,5,6], B = [13, 21, 34]
#
# The task is to create a list with the elements of A and B in a single dimension with output:
#
# A_B = [1,2,3,4,5,6,13, 21, 34]
#
# Which of the following option is the best way to create this list?

# %%
A = [1,2,3,4,5,6]
B = [13, 21, 34]
A.extend(B)
A
# Out:
# [1, 2, 3, 4, 5, 6, 13, 21, 34]

# %% [markdown]
# ## Importing the required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Question 2

# %%
np.identity(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %% [markdown]
# ## Question 3

# %% [markdown]
# Downloading the dataset

# %%
url = 'http://bit.ly/HDSC-Dataset'
data = pd.read_csv(url)

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#                 record_id  ...  fuel_cost_per_mmbtu
# 0   f1_fuel_1994_12_1_0_7  ...                1.121
# 1  f1_fuel_1994_12_1_0_10  ...                1.120
# 2   f1_fuel_1994_12_2_0_1  ...                1.650
# 3   f1_fuel_1994_12_2_0_7  ...                1.970
# 4  f1_fuel_1994_12_2_0_10  ...                2.570
#
# [5 rows x 11 columns]

# %%
df.groupby('fuel_type_code_pudl')['fuel_cost_per_unit_burned'].mean()
# Out:
# fuel_type_code_pudl
# coal         67.421830
# gas          13.659397
# nuclear    4955.157002
# oil         168.877086
# other        18.253856
# waste        19.518122
# Name: fuel_cost_per_unit_burned, dtype: float64

# %% [markdown]
# ## Question 4
# What is the standard deviation and 75th percentile of the measure of energy per unit (Fuel_mmbtu_per_unit) in two decimal places?

# %%
round(df.describe(),2)
# Out:
#        utility_id_ferc1  ...  fuel_cost_per_mmbtu
# count          29523.00  ...             29523.00
# mean             118.60  ...                19.30
# std               74.18  ...              2091.54
# min                1.00  ...               -41.50
# 25%               55.00  ...                 1.94
# 50%              122.00  ...                 4.13
# 75%              176.00  ...                 7.74
# max              514.00  ...            359278.00
#
# [8 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29523 entries, 0 to 29522
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   record_id                     29523 non-null  object
#  1   utility_id_ferc1              29523 non-null  int64
#  2   report_year                   29523 non-null  int64
#  3   plant_name_ferc1              29523 non-null  object
#  4   fuel_type_code_pudl           29523 non-null  object
#  5   fuel_unit                     29343 non-null  object
#  6   fuel_qty_burned               29523 non-null  float64
#  7   fuel_mmbtu_per_unit           29523 non-null  float64
#  8   fuel_cost_per_unit_burned     29523 non-null  float64
#  9   fuel_cost_per_unit_delivered  29523 non-null  float64
#  10  fuel_cost_per_mmbtu           29523 non-null  float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 2.5+ MB

# %% [markdown]
# #Question 6
# ## Which feature has missing values and what is the total number of missing value and percentage of the missing rows as a factor of the total number of rows in three decimal places?

# %%
df.isna().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
df.isna().sum()/len(df.isna().sum())
# Out:
# record_id                        0.000000
# utility_id_ferc1                 0.000000
# report_year                      0.000000
# plant_name_ferc1                 0.000000
# fuel_type_code_pudl              0.000000
# fuel_unit                       16.363636
# fuel_qty_burned                  0.000000
# fuel_mmbtu_per_unit              0.000000
# fuel_cost_per_unit_burned        0.000000
# fuel_cost_per_unit_delivered     0.000000
# fuel_cost_per_mmbtu              0.000000
# dtype: float64

# %%
import plotly.express as px
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (10, 6)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
df.columns
# Out:
# Index(['record_id', 'utility_id_ferc1', 'report_year', 'plant_name_ferc1',
#        'fuel_type_code_pudl', 'fuel_unit', 'fuel_qty_burned',
#        'fuel_mmbtu_per_unit', 'fuel_cost_per_unit_burned',
#        'fuel_cost_per_unit_delivered', 'fuel_cost_per_mmbtu'],
#       dtype='object')

# %% [markdown]
# Which of the following fuel type code has the lowest average fuel cost per unit burned?

# %%
fig = px.scatter(df, 
                 x='fuel_type_code_pudl', 
                 y='fuel_cost_per_unit_burned', 
                 color='report_year', 
                 opacity=0.8, 
                 hover_data=['report_year'], 
                 title='Fuel type code to Fuel cost')
fig.update_traces(marker_size=5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="cbb70e8f-1766-49f4-83fa-4e831be15bb2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cbb70e8f-1766-49f4-83fa-4e831be15bb2")) {
#                     Plotly.newPlot(
#                         'cbb70e8f-1766-49f4-83fa-4e831be15bb2',
# ...

# %% [markdown]
# # Question 5
# What is the skewness and kurtosis for the fuel quantity burned in two decimal places?

# %%
df['fuel_qty_burned'].skew()
# Out:
# 15.851495469109503

# %%
df['fuel_qty_burned'].kurt()
# Out:
# 651.3694501337732

# %% [markdown]
# ### Question 8
# Correlation between variable

# %%
df.corr()
# Out:
#                               utility_id_ferc1  ...  fuel_cost_per_mmbtu
# utility_id_ferc1                      1.000000  ...             0.006122
# report_year                           0.093323  ...             0.010261
# fuel_qty_burned                      -0.057447  ...            -0.001896
# fuel_mmbtu_per_unit                  -0.066946  ...            -0.005884
# fuel_cost_per_unit_burned            -0.037863  ...            -0.000437
# fuel_cost_per_unit_delivered         -0.016414  ...            -0.000109
# fuel_cost_per_mmbtu                   0.006122  ...             1.000000
#
# [7 rows x 7 columns]

# %%
corr_df = df.corr()
corr_df['fuel_cost_per_unit_burned']
# Out:
# utility_id_ferc1               -0.037863
# report_year                     0.013599
# fuel_qty_burned                -0.018535
# fuel_mmbtu_per_unit            -0.010034
# fuel_cost_per_unit_burned       1.000000
# fuel_cost_per_unit_delivered    0.011007
# fuel_cost_per_mmbtu            -0.000437
# Name: fuel_cost_per_unit_burned, dtype: float64

# %% [markdown]
# Question 9

# %%
coal_df = df.loc[df.fuel_type_code_pudl == 'coal']

# %%
coal_df = coal_df.groupby('report_year')['fuel_cost_per_unit_burned'].sum()

# %%
year_1998, year_1994 = coal_df.iloc[4], coal_df.iloc[0]

# %%
round(((year_1998 - year_1994) / year_1994) * 100)
# Out:
# -21

# %% [markdown]
# # Question 10
# Which year has the highest average fuel cost per unit delivered?

# %%
fig = px.scatter(df, 
                 x='report_year', 
                 y='fuel_cost_per_unit_delivered', 
                 color='report_year', 
                 opacity=0.8, 
                 hover_data=['report_year'], 
                 title='Report_year/Cost_Delivered')
fig.update_traces(marker_size=5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="45678180-e3af-43ab-8faf-38199b8102a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("45678180-e3af-43ab-8faf-38199b8102a4")) {
#                     Plotly.newPlot(
#                         '45678180-e3af-43ab-8faf-38199b8102a4',
# ...

# %%
df.groupby('report_year')['fuel_cost_per_unit_delivered'].mean().sort_values(ascending=False)
# Out:
# report_year
# 1997    11140.197239
# 1996     9196.705948
# 2000      985.362877
# 2009      652.694163
# 2018      499.269966
# 2015      326.535511
# 1998      287.154420
# 2014      192.737183
# 2013      172.307591
# 2004      139.524275
# 2016      103.901761
# 2010       91.862105
# 1994       63.636060
# 2012       60.994502
# 2001       60.050396
# 2011       59.774667
# 2008       58.588197
# 2003       55.663493
# 2002       47.594361
# 2017       46.196861
# 2007       43.325023
# 2005       41.438184
# 2006       38.657484
# 1995       32.735269
# 1999       25.551627
# Name: fuel_cost_per_unit_delivered, dtype: float64
